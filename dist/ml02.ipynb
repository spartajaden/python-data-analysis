# %% [markdown]
# # 결정나무트리

# %%
from sklearn.datasets import load_iris
from sklearn.datasets import load_wine
from sklearn.datasets import load_breast_cancer
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier, plot_tree

# plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

iris = load_iris()
x, y = iris.data, iris.target

# %%
# 결정나무 학습
dt = DecisionTreeClassifier(max_depth=2, random_state=42)
dt.fit(x, y)

plt.figure(figsize=(12, 8))
plot_tree(dt, feature_names=iris.feature_names, class_names=iris.target_names, filled=True)
plt.show()
print(iris.feature_names)
print(iris.target_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.datasets import load_wine

wine = load_wine()
x, y = wine.data, wine.target

# 결정나무 학습
dt = DecisionTreeClassifier(max_depth=3, random_state=42)
dt.fit(x, y)

plt.figure(figsize=(18, 8))
plot_tree(dt, feature_names=wine.feature_names, class_names=wine.target_names, filled=True, fontsize=12)
plt.show()

print(wine.feature_names)
print(wine.target_names)
# Out:
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# ['class_0' 'class_1' 'class_2']

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.datasets import load_breast_cancer

cancer = load_breast_cancer()
x, y = cancer.data, cancer.target

# 결정나무 학습
dt = DecisionTreeClassifier(max_depth=3, random_state=42)
dt.fit(x, y)

plt.figure(figsize=(18, 8))
plot_tree(dt, feature_names=cancer.feature_names, class_names=cancer.target_names, filled=True, fontsize=12)
plt.show()

print(cancer.feature_names)
print(cancer.target_names)
# Out:
# ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']
# ['malignant' 'benign']

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree

data = {
    '공부시간(일)': [1, 5, 8, 2, 6, 0, 9, 3, 7, 4],
    '수면시간(시)': [8, 6, 7, 4, 7, 5, 8, 3, 6, 9],
    '출석률(%)': [60, 90, 95, 50, 85, 40, 100, 55, 90, 70],
    '합격여부': ['불합격','합격','합격','불합격','합격','불합격','합격','불합격','합격','합격']
}

df = pd.DataFrame(data)
df.columns = ['day', 'h', 'per', 'pass']
x = df[['day', 'h', 'per']]
y = df[['pass']]

# 결정나무 학습
dt = DecisionTreeClassifier(max_depth=1, random_state=42)
dt.fit(x, y)

plt.figure(figsize=(12, 8))
plot_tree(dt, feature_names=x.columns, class_names= ['불합격', '합격'] , filled=True, rounded=True, fontsize=16)
plt.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree


data2 = {
'기온(도)': [28, 15, 10, 33, 20, 8, 25, 35, 18, 12],
'습도(%)': [80, 50, 40, 90, 60, 30, 55, 95, 45, 35],
'바람(m/s)': [3, 1, 5, 2, 4, 7, 1, 3, 6, 2],
'운동여부': ['안함','함','함','안함','함','안함','함','안함','안함','함']
}

df = pd.DataFrame(data2)
x = df[['기온(도)', '습도(%)', '바람(m/s)']]
y = df[['운동여부']]

# 결정나무 학습
dt = DecisionTreeClassifier(max_depth=2, random_state=42)
dt.fit(x, y)

plt.figure(figsize=(12, 8))
plot_tree(dt, feature_names=x.columns, class_names= ['안함', '함'] , filled=True, rounded=True, fontsize=16)
plt.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree


data3 = {
    '집에서_거리(분)':[10, 60, 15, 50, 5, 40, 20, 90, 30, 5],
    '카페_경력(개월)':[12, 0, 6, 2, 24, 0, 1, 0, 3, 18],
    '지각_경험(회)': [0, 3, 1, 5, 0, 2, 0, 10, 0, 1],
    '합격여부': ['합격','불합격','합격','불합격','합격','불합격','합격','불합격','합격','합격']
}

df = pd.DataFrame(data)
x = df[['집에서_거리(분)', '카페_경력(개월)', '지각_경험(회)']]
y = df[['합격여부']]

# 결정나무 학습
dt = DecisionTreeClassifier(max_depth=2, random_state=42)
dt.fit(x, y)

plt.figure(figsize=(12, 8))
plot_tree(dt, feature_names=x.columns, class_names= ['안함', '함'] , filled=True, rounded=True, fontsize=16)
plt.show()
