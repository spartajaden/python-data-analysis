# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4,5,6,7])
plt.show()

# %%
plt.plot([39,20,5,33,45])
plt.show()

# %%
plt.plot([10,20,30,40,50],[5,8,11,25,77])
plt.show()

# %%
plt.plot([10,20,30,40,50],[5,8,11,25,77],'bo') # r:red, b:bule, g:green, .:작은점 o:점, -:실선, --:점선
plt.show()

# %%
import numpy as np
data = np.arange(0.0,5.0,0.1)
plt.plot(data,'-r',data**2,'b-',data**3,'g-',data**3,'g.')
plt.show()

# %%
data_dic = {'x':[1,2,3,4,5],'y':[11,13,15,23,14]}
plt.plot(data_dic['x'],data_dic['y'])
plt.show()

# %%
#레이블설정하기
plt.plot(data_dic['x'],data_dic['y'])
fontstyle = {'family':'serif','color':'b','weight':'bold','size':14}
plt.xlabel('X-data',loc='right',labelpad=15,fontdict=fontstyle)
plt.ylabel('Y-data',loc='top',labelpad=20,fontdict=fontstyle)
plt.show()

# %%
# 범례표시하기
import numpy as np
data = np.arange(0.0,5.0,0.1)
plt.plot(data,'-r',label='Volume (%)')
plt.plot(data**2,'b-',label='Power (W)')
plt.plot(data**3,'g-',label='Ea (EA)')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### 축 스케일 지정하기

# %% [markdown]
# 1) 데이터 분석에서 로그스케일
#    - 인구
#    - 파일크기
#    - 조회수
#    - 가격
#    - 센서값
# 2) 반대로 음수 스케일
#    - 수익률
#    - 오차
#    - 전압
#    - 편차
#    - 온도 변화량
#    - 손익

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,5,100)
y = np.exp(x)
plt.plot(x,y)
plt.yscale('log') # linear
plt.show()

# %%
x = np.linspace(-10,10,100)
y = x**3
plt.plot(x,y)
plt.xscale('symlog') # log 는 양수만, symlog 음수겸용
plt.show()

# %%
# linespace 응용

# %%
x1 = np.linspace(0,2*np.pi,10)
x2 = np.linspace(0,2*np.pi,30)
x3 = np.linspace(0,2*np.pi,100)
y1 = np.sin(x1)
y2 = np.sin(x2) + 0.25
y3 = np.sin(x3) + 0.5
plt.plot(x1, y1, color='r')
plt.plot(x2, y2, color='g')
plt.plot(x3, y3, color='b')
plt.show()

# %% [markdown]
# ### 확장기능, 그래프 영역 채우기

# %%
x = [10,20,30,40,50]
y = [5,8,11,26,75]
plt.plot(x,y)
plt.fill_between(x, y)
plt.show()

# %%
x = [10,20,30,40,50]
y = [5,8,11,26,75]
plt.plot(x,y)
plt.fill_between(x[2:4], y[2:4], alpha=0.3)
plt.show()

# %% [markdown]
# ### 그래프 사이채우기

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,10)
y1 = x*2
y2 = x*2 + 5
plt.plot(x, y1)
plt.plot(x, y2)
plt.fill_between(x[3:7],y1[3:7],y2[3:7],alpha=0.3,color='lightgreen')
plt.show()

# %% [markdown]
# ![image.png](attachment:91bec638-5e52-466c-a7b2-13abe326192d.png)

# %%
x = np.arange(0,10)
y1 = x*2
y2 = x*2 + 5
print(y1)
print(y2)
plt.plot(x, y1)
plt.plot(x, y2)
plt.fill([3 ,3 ,6.5,6.5],[4 ,13 ,20 ,11], alpha=0.3,color="pink")
plt.show()

# %% [markdown]
# ### 그리드 설정하기

# %%
x = np.linspace(0,5,100)
y = np.exp(x)
plt.plot(x,y)
plt.fill_between(x[40:80],y[40:80], color='violet', alpha=0.7)
plt.grid(axis='x')
plt.show()

# %% [markdown]
# ### 수평선 그리기

# %%
x = np.arange(0, 4, 0.5)
plt.plot(x, x+1, 'bo')
plt.plot(x,x**2-4,'g--')
plt.plot(x,-2*x+3,'r:')
plt.hlines(-0.62,0.5,3,color='red', linewidth=3)  # y높이, x시작, x끝
plt.vlines(0.6,-3,4,color='blue', linestyle='--', linewidth=2)  # x위치, y바닥 , y 높이
plt.show()

# %% [markdown]
# ### 막대그래프

# %%
# 세로막대 bar, 가로막대 barh
x = np.arange(3)
year = ['2024','2025','2026']
value = [100,400,800]
plt.bar(x, value, color=['r','g','b'])
plt.xticks(x, year)
plt.show()

# %%
# 세로막대 bar, 가로막대 barh
x = np.arange(3)
year = ['2024','2025','2026']
value = [100,400,800]
plt.barh(x, value, color=['r','g','b'])
plt.yticks(x, year)
plt.show()

# %%
# 막대 폭 지정
x = np.arange(3)
year = ['2024','2025','2026']
value = [100,400,800]
plt.bar(x, value, color=['r','g','b'], width=[0.3,0.5,1])
plt.xticks(x, year)
plt.show()

# %%
# 막지 엣지 색상, 두께
x = np.arange(3)
year = ['2024','2025','2026']
value = [100,400,800]
plt.barh(x, value, color=['r','g','b'], linewidth=3, edgecolor=['pink','y','cyan'] )
plt.yticks(x, year)
plt.show()

# %%
# 막지 엣지 색상, 두께
x = np.arange(3)
year = ['2024','2025','2026']
value = [100,400,800]
colors = ['r' if v < 400 else 'y' for v in value]
plt.barh(x, value, color='y', linewidth=3, edgecolor=colors )
plt.yticks(x, year)
plt.show()

# %% [markdown]
# ### 산점도 그래프

# %%
# 산점도 크기
np.random.seed(20)
n = 50
x = np.random.rand(n)
y = np.random.rand(n)

size = (20 * np.random.rand(n))**2
plt.scatter(x,y, s=size)
plt.show()

# %%
# 산점도 색상
np.random.seed(20)
n = 50
x = np.random.rand(n)
y = np.random.rand(n)

size = (20 * np.random.rand(n))**2
color = np.random.rand(n)
plt.scatter(x,y, s=size, c=color)
plt.show()

# %%
# 산점도 투명도 컬러맵
np.random.seed(20)
n = 50
x = np.random.rand(n)
y = np.random.rand(n)

size = (20 * np.random.rand(n))**2
color = np.random.rand(n)
plt.scatter(x,y, s=size, c=color, alpha=0.5, cmap='Spectral')
plt.colorbar()
plt.show()

# %% [markdown]
# ### 파이차트 그래프

# %%
# 파이차트기본
ratio = [33,15,12,40]
labels = ['Apple','Banana', 'Melon', 'Orange']

plt.pie(ratio, labels=labels, autopct='%.1f%%')
plt.show()

# %%
# 파이차트 컬러 강조
ratio = [33,15,22,30]
labels = ['Apple','Banana', 'Melon', 'Orange']
# colors = ['#ffff00' if v < 20 else 'whitesmoke' for v in ratio ]
colors = ['red','yellow','lightgreen','orange']
wedgeprops={'width':0.7,'edgecolor':'w','linewidth':5}
plt.pie(ratio, labels=labels, colors=colors, autopct='%.1f%%', wedgeprops=wedgeprops)
plt.show()

# %% [markdown]
# ### 히트맵그리기

# %%
# 히트맵 기본값
arr = np.random.standard_normal((30,40))
plt.matshow(arr)
plt.colorbar()
plt.show()

# %%
# 히트맵 기본값
arr = np.random.standard_normal((30,40))
plt.matshow(arr, cmap='winter')
plt.colorbar()
plt.show()

# %% [markdown]
# ### 멀티 그래프

# %%
x1 = np.linspace(0.0,5.0,100)
x2 = np.linspace(0.0,2.0,50)

y1 = np.cos(2*np.pi*x1)* np.exp(-x1)
y2 = np.cos(2*np.pi*x2)

plt.subplot(2, 1, 1)
plt.plot(x1,y1,'o-')
plt.title('1st Graph')

plt.subplot(2, 1, 2)
plt.plot(x2,y2,'.-')
plt.title('2nd Graph')

plt.tight_layout()
plt.show()

# %%
# 세로막대 bar, 가로막대 barh
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(4)

subject = ['Python','SQL','Pandas','Matplotlib']
value = [88,81,90,86]
bars = plt.bar(x, value, color = ['skyblue','lightgreen','salmon','plum'])
plt.xticks(x, subject)

plt.bar_label(bars, padding=3, fontproperties={'weight':'bold'})

data_dic = {'x':['Python','SQL','Pandas','Matplotlib'],'y':[88,81,90,86]}
plt.plot(data_dic['x'],data_dic['y'])
fontstyle = {'family':'serif','color':'black','weight':'bold','size':14}
plt.xlabel('Subject',loc='center',labelpad=15,fontdict=fontstyle)
plt.ylabel('Score',loc='center',labelpad=20,fontdict=fontstyle)

plt.ylim(0, 110) # 100점 레이블 글자가 천장에 딱 붙지 않도록 그래프 범위를 110까지 살짝 여유를 줍니다.
plt.yticks([0, 20, 40, 60, 80, 100]) # y축 눈금에 100을 명시적으로 표시합니다.

plt.show()

# %%
subjects = ['Python','SQL','Pandas','Matplotlib']
scores = [88, 81, 90, 86]
colors = ['skyblue','lightgreen','salmon','plum']

# %%
hours = [1, 2, 3, 4, 5, 6, 7, 8]
scores = [45, 50, 58, 64, 70, 76, 85, 90]
# cmap='virid'

# %%
# !pip install --upgrade numpy matplotlib opencv-python-headless scipy scikit-learn numba
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 7.1 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 13.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 13.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.0 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.3
#     Uninstalling scipy-1.11.3:
#       Successfully uninstalled scipy-1.11.3
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.40.1
#     Uninstalling llvmlite-0.40.1:
#       Successfully uninstalled llvmlite-0.40.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.1
#     Uninstalling scikit-learn-1.3.1:
#       Successfully uninstalled scikit-learn-1.3.1
#   Attempting uninstall: numba
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0,2*np.pi,0.01)
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()

# %%
# !pip install qrcode pillow 
# opencv-python
# !pip install opencv-python-headless
# qrcode QR CODE 생성기
# pillow 이미지 저장처리
# opencv-python QR코드인식

# %%
import qrcode

data = "안녕하세요 QR은 처음이지"

img = qrcode.make(data)
img.save("myqr.png")
print("QR 코드 생성 완료!")
# Out:
# QR 코드 생성 완료!

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open("myqr.png")
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
import cv2
img = cv2.imread("myqr.png")
detector = cv2.QRCodeDetector()
data, points, _ = detector.detectAndDecode(img)
print("인식된 내용:", )
# Out:
# 인식된 내용: 안녕하세요 QR은 처음이지

# %%
import cv2
