# %% [markdown]
# # 교통사고유형별 발생분석

# %% [markdown]
# - https://www.data.go.kr/
# - 표준데이터셋
# - 전국교통사고다발지역표준데이터
# - 최신 csv 파일로 저장

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

file_path = 'dataset/전국교통사고다발지역표준데이터.csv'
df = pd.read_csv(file_path, encoding="EUC-KR")
df #['사고유형구분'].unique()
# Out:
#        사고지역관리번호  사고연도  사고유형구분      위치코드    사고다발지역시도시군구  \
# 0       2025108  2024   보행어린이  52180001   전북특별자치도 정읍시1
# 1       2025108  2024   보행어린이  50110004   제주특별자치도 제주시4
# 2       2025108  2024   보행어린이  50110003   제주특별자치도 제주시3
# 3       2025108  2024   보행어린이  50110002   제주특별자치도 제주시2
# 4       2025108  2024   보행어린이  50110001   제주특별자치도 제주시1
# ...         ...   ...     ...       ...            ...
# 12775   2014105  2013    보행노인  11140002      서울특별시 중구2
# 12776   2014105  2013    보행노인  11140001      서울특별시 중구1
# 12777   2014105  2013    보행노인  11110002     서울특별시 종로구2
# 12778   2014105  2013    보행노인  11110001     서울특별시 종로구1
# 12779   2014095  2013  스쿨존어린이  50130001  제주특별자치도 서귀포시1
#
#                                사고지역위치명  사고건수  사상자수  사망자수  중상자수  경상자수  부상신고자수  \
# 0            전북특별자치도 정읍시 상동(한솔초등학교 부근)     3     3     0     0     3       0
# 1       제주특별자치도 제주시 일도이동(꼬마스쿨 어린이집 부근)     3     3     0     0     2       1
# ...

# %%
raw_data = df.copy()
raw_data = raw_data.groupby('사고유형구분')['사고건수'].sum().reset_index(name="count")
raw_data = raw_data.sort_values('count',ascending=False)
raw_data.columns = ['type','count']
raw_data.head()
# raw_data['type']
# Out:
#      type  count
# 0    보행노인  26098
# 3     자전거  26040
# 1   보행어린이   4111
# 2  스쿨존어린이   1095

# %%
import matplotlib.pyplot as plt

# 1. 한글 폰트 설정 (나눔 폰트가 설치되어 있는 경우)
plt.rcParams['font.family'] = 'NanumGothic'

# 2. 마이너스 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

raw_data.plot(
    kind='pie',
    y='count',
    labels= raw_data['type'],
    figsize=(7,7),
    startangle=90,
    autopct='%2.1f%%',
    title='각 사고 유형별 총 발생 통계',
    cmap = matplotlib.cm.Blues
)
plt.show()

# %%
ex_data.head()
# Out:
#    사고지역관리번호  year   type      위치코드   사고다발지역시도시군구  \
# 0   2025108  2024  보행어린이  52180001  전북특별자치도 정읍시1
# 1   2025108  2024  보행어린이  50110004  제주특별자치도 제주시4
# 2   2025108  2024  보행어린이  50110003  제주특별자치도 제주시3
# 3   2025108  2024  보행어린이  50110002  제주특별자치도 제주시2
# 4   2025108  2024  보행어린이  50110001  제주특별자치도 제주시1
#
#                            사고지역위치명  accident  사상자수  사망자수  중상자수  경상자수  부상신고자수  \
# 0        전북특별자치도 정읍시 상동(한솔초등학교 부근)         3     3     0     0     3       0
# 1   제주특별자치도 제주시 일도이동(꼬마스쿨 어린이집 부근)         3     3     0     0     2       1
# 2       제주특별자치도 제주시 도남동(도남초등학교 부근)         3     3     0     0     3       0
# 3  제주특별자치도 제주시 연동(신제주초등학교입구교차로 부근)         3     3     0     1     1       1
# 4       제주특별자치도 제주시 노형동(세빛어린이집 부근)         4     5     0     2     2       1
#
#           위도          경도                                        사고다발지역폴리곤정보  \
# 0  35.560543  126.873488  { type: Polygon, coordinates: [ [ [943222, 172...
# ...

# %%
ex_data.columns
# Out:
# Index(['사고지역관리번호', 'year', 'type', '위치코드', '사고다발지역시도시군구', '사고지역위치명',
#        'accident', '사상자수', '사망자수', '중상자수', '경상자수', '부상신고자수', '위도', '경도',
#        '사고다발지역폴리곤정보', '데이터기준일자', '제공기관코드', '제공기관명'],
#       dtype='object')

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib # matplotlib 라이브러리 직접 import 추가

# 한글 폰트 설정 (리눅스 환경에서 나눔 폰트가 설치되어 있는 경우)
plt.rcParams['font.family'] = 'NanumGothic'
# 마이너스 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

if not os.path.exists('./chart'):
    os.makedirs('./chart')
    
file_path = 'dataset/전국교통사고다발지역표준데이터.csv'
df = pd.read_csv(file_path, encoding="EUC-KR")

ex_data = df.copy()
ex_data = ex_data.rename(columns={'사고연도':'year','사고유형구분':'type','사고건수':'accident'})

#방법1a
arr_data = list(ex_data['type'].unique())

#방법1b
# arr_data = list(set(ex_data['type']))

#방법2a
data_list = [g for _ , g in ex_data.groupby('type')]

#방법2b
# data_list = []
# for a in arr_data:
#     data_list.append(ex_data[ ex_data['type']==a ])

total = []
for d in data_list:
    result = d.groupby('year')['accident'].sum().reset_index(name='count')
    total.append(result)

for x in range(len(arr_data)):
    total[x].plot(
        kind='pie',
        y='count',
        labels= total[x]['year'],
        figsize=(7,7),
        startangle=90,
        autopct='%2.1f%%',
        title=f'연도별 {arr_data[x]} 사고발생 통계',
        cmap = matplotlib.cm.Blues
    )
plt.savefig(f'./chart/chart{x}.png')
plt.show()

# %%
from IPython.display import display, HTML

html_raw = f"""
<div style="display: flex ;flex-wrap:wrap;width:1000px;">
    <div style="flex: 1; min-width:300px";>
        <div style="padding: 10px 0 10px 80px;">
        <h3>Data Table</h3>
        {raw_data.to_html(index=False)}
        </div>
    </div>"""
for v in range(len(arr_data)):
    html_raw += f"""<div style="flex: 1; padding: 10px; min-width:300px">
            <h3>Pie Chart{v+1}</h3>
            <img src="./chart/chart{v}.png" alt="Pie Chart">
        </div>"""
html_raw +=f"""</div> """

display(HTML(html_raw))
# Out:
# <div style="display: flex ;flex-wrap:wrap;width:1000px;">
#     <div style="flex: 1; min-width:300px";>
#         <div style="padding: 10px 0 10px 80px;">
#         <h3>Data Table</h3>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>type</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>보행노인</td>
#       <td>26098</td>
#     </tr>
#     <tr>
#       <td>자전거</td>
#       <td>26040</td>
#     </tr>
#     <tr>
#       <td>보행어린이</td>
#       <td>4111</td>
#     </tr>
#     <tr>
#       <td>스쿨존어린이</td>
#       <td>1095</td>
#     </tr>
#   </tbody>
# </table>
#         </div>
#     </div><div style="flex: 1; padding: 10px; min-width:300px">
#             <h3>Pie Chart1</h3>
#             <img src="./chart/chart0.png" alt="Pie Chart">
#         </div><div style="flex: 1; padding: 10px; min-width:300px">
#             <h3>Pie Chart2</h3>
# ...
